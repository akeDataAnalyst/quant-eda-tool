# %% [markdown]
# #### Main Streamlit App

# %%
import streamlit as st
import pandas as pd
import numpy as np  
from utils import load_data, data_quality_report, clean_data, basic_eda, advanced_eda

# Page config
st.set_page_config(page_title="Quant EDA Tool", layout="wide")
st.title("🧮 Internal Quant Tool for Exploratory Data Analysis")
st.markdown("""
This internal utility supports quantitative researchers by automating:
- Data quality validation
- One-click cleaning
- Basic and advanced exploratory analysis

Upload your own tick dataset or use the built-in synthetic BTCUSDT example.
""")

# Sidebar
st.sidebar.header("Data Source")
use_sample = st.sidebar.checkbox("Use synthetic BTCUSDT tick data (demo)", value=True)

if use_sample:
    df_raw = load_data(None, use_sample=True)
    st.sidebar.success(f"Loaded synthetic_tick_data.csv ({len(df_raw):,} rows)")
else:
    uploaded_file = st.sidebar.file_uploader(
        "Upload CSV (required columns: timestamp, price, volume)",
        type=['csv']
    )
    if uploaded_file is None:
        st.info("👆 Please upload a CSV file or check 'Use synthetic data' to continue.")
        st.stop()
    df_raw = load_data(uploaded_file)

# Raw data preview
with st.expander("🔍 View Raw Data Preview", expanded=False):
    st.dataframe(df_raw.head(1000))
    st.write(f"Shape: {df_raw.shape}")

# Data Quality Report
data_quality_report(df_raw)

# Cleaning Section
st.subheader("🧹 Data Cleaning")
if st.button("Clean Dataset (dedupe, fix negatives/outliers, forward-fill price)"):
    with st.spinner("Cleaning data..."):
        df_cleaned = clean_data(df_raw)
    st.success(f"✅ Cleaning complete: {len(df_cleaned):,} rows retained")
    
    # Save to session state
    st.session_state.df_clean = df_cleaned
    st.session_state.cleaned = True

# Check if we have cleaned data
if 'df_clean' not in st.session_state:
    st.info("👆 Click the 'Clean Dataset' button above to enable analysis tabs.")
    st.stop()

# Retrieve cleaned data safely
df_clean = st.session_state['df_clean'].copy()

# CRITICAL: Create log_return here so it's always available for both tabs
df_clean['log_return'] = np.log(df_clean['price'] / df_clean['price'].shift(1))

# Now set timestamp as index
df_clean = df_clean.set_index('timestamp')

st.success(f"📊 Analysis ready — using cleaned dataset with {len(df_clean):,} rows")

# Analysis Tabs
tab1, tab2 = st.tabs(["Basic EDA", "Advanced Analysis"])

with tab1:
    basic_eda(df_clean.copy().reset_index())  # Functions expect 'timestamp' column

with tab2:
    advanced_eda(df_clean.copy().reset_index())

# Footer
st.caption("Built with Python • Pandas • NumPy • Streamlit | Clean, readable code for quant research support")
st.caption("Developed by Aklilu Abera | Quant EDA Tool for Research Support")
# Out:
# 2026-01-01 17:08:19.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:20.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:25.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:25.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:25.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:26.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-01 17:08:27.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\streamlit\runtime\state\session_state.py:410, in SessionState.__getitem__(self, key)
#     409 try:
# --> 410     return self._getitem(widget_id, key)
#     411 except KeyError:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\streamlit\runtime\state\session_state.py:455, in SessionState._getitem(self, widget_id, user_key)
#     454 # We'll never get here
# --> 455 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 60
#      57     st.stop()
#      59 # Retrieve cleaned data safely
# ---> 60 df_clean = st.session_state['df_clean'].copy()
#      62 # CRITICAL: Create log_return here so it's always available for both tabs
#      63 df_clean['log_return'] = np.log(df_clean['price'] / df_clean['price'].shift(1))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\streamlit\runtime\state\session_state_proxy.py:100, in SessionStateProxy.__getitem__(self, key)
#      98 key = str(key)
#      99 require_valid_user_key(key)
# --> 100 return get_session_state()[key]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\streamlit\runtime\state\safe_session_state.py:94, in SafeSessionState.__getitem__(self, key)
#      92 self._yield_callback()
#      93 with self._lock:
# ---> 94     return self._state[key]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\streamlit\runtime\state\session_state.py:412, in SessionState.__getitem__(self, key)
#     410     return self._getitem(widget_id, key)
#     411 except KeyError:
# --> 412     raise KeyError(_missing_key_error_message(key))
#
# KeyError: 'st.session_state has no key "df_clean". Did you forget to initialize it? More info: https://docs.streamlit.io/develop/concepts/architecture/session-state#initialization'
